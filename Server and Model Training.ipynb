# %%
pip install torch datasets transformers librosa

# %%
! pip install git+https://github.com/openai/whisper.git
! pip install sounddevice wavio
! pip install ipywebrtc notebook
! pip install pydub
! pip install googletrans==4.0.0rc1
# ! pip install translators==5.4.1
# Out:
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-ufh8lg4n
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-ufh8lg4n
#   Resolved https://github.com/openai/whisper.git to commit 173ff7dd1d9fb1c4fddea0d41d704cfefeb8908c
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
# !apt install ffmpeg
# !apt-get install libportaudio2
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libportaudio2 is already the newest version (19.6.0-1.1).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.

# %%
# !pip install pydub transformers torch

# %%
import os
import numpy as np

try:
    import tensorflow  # required in Colab to avoid protobuf compatibility issues
except ImportError:
    pass

import torch
import pandas as pd
import whisper
import torchaudio

from ipywebrtc import AudioRecorder, CameraStream
from IPython.display import Audio, display
import ipywidgets as widgets

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

# %%
DEVICE
# Out:
# 'cuda'

# %%
from google.colab import output
output.enable_custom_widget_manager()

# %%
camera = CameraStream(constraints={'audio': True,'video':False})
recorder = AudioRecorder(stream=camera)
recorder
# Out:
# AudioRecorder(audio=Audio(value=b'', format='webm'), stream=CameraStream(constraints={'audio': True, 'video': …

# %%
with open('recording.webm', 'wb') as f:
    f.write(recorder.audio.value)
# !ffmpeg -i recording.webm -ac 1 -f wav my_recording.wav -y -hide_banner -loglevel panic

# %%
# !pip install langdetect

# %%
# from datasets import Dataset

# # Read the .data file manually
# data_file = '/content/drive/MyDrive/Telugu/tr.data'
# data = []

# with open(data_file, 'r') as file:
#     for line in file:
#         audio_path, transcription = line.strip().split(' ', 1)  # Split each line by the first space
#         data.append({'audio_path': audio_path, 'transcription': transcription})

# # Create a Dataset from the data
# dataset = Dataset.from_pandas(pd.DataFrame(data))

# # Print column names and the first record
# print(dataset.column_names)
# print(dataset[0])

# %%
# from datasets import Dataset, DatasetDict
# import pandas as pd
# from sklearn.model_selection import train_test_split

# # Read the .data file manually
# data_file = '/content/drive/MyDrive/Telugu/tr.data'
# data = []

# with open(data_file, 'r') as file:
#     for line in file:
#         audio_path, transcription = line.strip().split(' ', 1)  # Split each line by the first space
#         data.append({'audio_path': audio_path, 'transcription': transcription})

# # Convert to a DataFrame
# df = pd.DataFrame(data)

# # Split the data into training and testing sets
# train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)

# # Create Dataset objects
# train_dataset = Dataset.from_pandas(train_df)
# test_dataset = Dataset.from_pandas(test_df)

# # Combine into a DatasetDict
# dataset = DatasetDict({
#     'train': train_dataset,
#     'test': test_dataset
# })

# # Print column names and the first record of the training set
# print(dataset.column_names)
# print(dataset['train'][1])

# # Print column names and the first record of the testing set
# print(dataset.column_names)
# print(dataset['test'][1])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-54cd5cd1a9a5> in <cell line: 32>()
#      30
#      31 # Print column names and the first record of the training set
# ---> 32 print(dataset.column_names)
#      33 # print(dataset['train'][1])
#      34
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#    6205
#    6206     @final
#
# AttributeError: 'DataFrame' object has no attribute 'column_names'

# %%
# from datasets import load_dataset, DatasetDict
# dataset = load_dataset('csv', data_files='/content/drive/MyDrive/Hindi.csv', column_names=['audio_path', 'transcription'])
# print(dataset.column_names)
# print(dataset['train'][0])  # Or dataset['test'][0] depending on the split
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# {'train': ['audio_path', 'transcription']}
# {'audio_path': 'train_hindimale_00649', 'transcription': ' हो सकता है, एक रात, गुप्त सूचना के आधार पर, अर्द्धसैनिक बलों की एक टुकड़ी ने, इसके एक बदकिस्मत घर के दरवाज़े पर, कुछ किशोर उग्रवादियों की, चिथड़ियाँ उड़ा दी हों '}

# %%
# from datasets import load_dataset, DatasetDict
# dataset = load_dataset('csv', data_files='/content/drive/MyDrive/Telugu/tr.data', column_names=['audio_path', 'transcription'])
# print(dataset.column_names)
# print(dataset['train'][0])  # Or dataset['test'][0] depending on the split
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Failed to read file '/content/drive/MyDrive/Telugu/tr.data' with error <class 'pandas.errors.ParserError'>: Error tokenizing data. C error: Expected 2 fields in line 7, saw 4
#
# ERROR:datasets.packaged_modules.csv.csv:Failed to read file '/content/drive/MyDrive/Telugu/tr.data' with error <class 'pandas.errors.ParserError'>: Error tokenizing data. C error: Expected 2 fields in line 7, saw 4
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/datasets/builder.py in _prepare_split_single(self, gen_kwargs, fpath, file_format, max_shard_size, job_id)
#    1852                 _time = time.time()
# -> 1853                 for _, table in generator:
#    1854                     if max_shard_size is not None and writer._num_bytes > max_shard_size:
#
# ...

# %%
from datasets import Dataset
import pandas as pd

# Read the .data file manually
data_file = '/content/drive/MyDrive/Telugu/tr.data'
data = []

with open(data_file, 'r', encoding='utf-8') as file:  # Ensure correct encoding
    for line in file:
        audio_path, transcription = line.strip().split(' ', 1)  # Split each line by the first space
        data.append({'audio_path': audio_path, 'transcription': transcription})

# Take only the first 700 records
data = data[:500]

# Create a Dataset from the data
dataset = Dataset.from_pandas(pd.DataFrame(data))

# Print column names and the first record
print(dataset.column_names)
print(dataset[0])
# Out:
# ['audio_path', 'transcription']
# {'audio_path': 'train_telugufemale_00001', 'transcription': 'నరకవాసి.'}

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from transformers import Wav2Vec2ForCTC,Wav2Vec2Processor
import librosa
import torch

processor = Wav2Vec2Processor.from_pretrained("anuragshas/wav2vec2-large-xlsr-53-telugu")

def preprocess_function(examples):
    audio_file = examples["audio_path"]
    full_path = f"/content/drive/MyDrive/Telugu/{audio_file}.wav"

    audio, sampling_rate = librosa.load(full_path, sr=16000)

    # Process audio and transcription
    inputs = processor(audio, sampling_rate=sampling_rate, return_tensors="pt", padding="longest")
    with processor.as_target_processor():
        labels = processor(examples["transcription"], return_tensors="pt", padding="longest").input_ids

    return {
        "input_values": inputs["input_values"].squeeze().tolist(),  # Ensure list format
        "labels": labels.squeeze().tolist()  # Ensure list format
    }

dataset = dataset.map(preprocess_function, remove_columns=["audio_path", "transcription"])
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/configuration_utils.py:364: UserWarning: Passing `gradient_checkpointing` to a config initialization is deprecated and will be removed in v5 Transformers. Using `model.gradient_checkpointing_enable()` instead, or if you are using the `Trainer` API, pass `gradient_checkpointing=True` in your `TrainingArguments`.
#   warnings.warn(
# ...

# %%
from datasets import load_dataset, DatasetDict
# dataset = dataset['train'].train_test_split(test_size=0.1)  # 10% for validation
dataset = dataset.train_test_split(test_size=0.1)

# Convert the split into DatasetDict format
dataset = DatasetDict({
    'train': dataset['train'],
    'validation': dataset['test']
})

print(dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['input_values', 'labels'],
#         num_rows: 450
#     })
#     validation: Dataset({
#         features: ['input_values', 'labels'],
#         num_rows: 50
#     })
# })

# %%
dataset['train']
# Out:
# Dataset({
#     features: ['input_values', 'labels'],
#     num_rows: 450
# })

# %%
from transformers import Wav2Vec2Processor
import torch
import numpy as np

class CustomDataCollatorForCTC:
    def __init__(self, processor, padding=True):
        self.processor = processor
        self.padding = padding

    def __call__(self, features):
        # Extracting audio features and labels
        audio_features = [torch.tensor(feature['input_values']) for feature in features]
        labels = [torch.tensor(feature['labels']) for feature in features]

        # Padding audio features
        max_length = max(len(f) for f in audio_features)
        padded_audio_features = torch.zeros((len(audio_features), max_length))
        for i, audio in enumerate(audio_features):
            padded_audio_features[i, :len(audio)] = audio

        # Padding labels
        max_label_length = max(len(l) for l in labels)
        padded_labels = torch.full((len(labels), max_label_length), -100)  # Use -100 for ignored labels
        for i, label in enumerate(labels):
            padded_labels[i, :len(label)] = label

        return {'input_values': padded_audio_features, 'labels': padded_labels}

data_collator = CustomDataCollatorForCTC(processor=processor)

# %%
from transformers import Trainer, TrainingArguments
from transformers import Wav2Vec2ForCTC

# Load the model and processor
model = Wav2Vec2ForCTC.from_pretrained("anuragshas/wav2vec2-large-xlsr-53-telugu")

# Define training arguments
training_args = TrainingArguments(
    output_dir="./results",
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=1,
    per_device_eval_batch_size=1,
    num_train_epochs=10,
    warmup_steps=500,
    weight_decay=0.01,
    logging_dir="./logs",
    logging_steps=10,
)

# Initialize Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    data_collator=data_collator,
    train_dataset=dataset["train"],
    eval_dataset=dataset["validation"],
    tokenizer=processor
)

# Start training
trainer.train()
# Out:
# pytorch_model.bin:   0%|          | 0.00/1.26G [00:00<?, ?B/s]
# Some weights of the model checkpoint at anuragshas/wav2vec2-large-xlsr-53-telugu were not used when initializing Wav2Vec2ForCTC: ['wav2vec2.encoder.pos_conv_embed.conv.weight_g', 'wav2vec2.encoder.pos_conv_embed.conv.weight_v']
# - This IS expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
from dataclasses import dataclass, field
from typing import Any, Dict, List, Optional, Union

@dataclass
class DataCollatorCTCWithPadding:
    """
    Data collator that will dynamically pad the inputs received.
    Args:
        processor (:class:`~transformers.Wav2Vec2Processor`)
            The processor used for proccessing the data.
        padding (:obj:`bool`, :obj:`str` or :class:`~transformers.tokenization_utils_base.PaddingStrategy`, `optional`, defaults to :obj:`True`):
            Select a strategy to pad the returned sequences (according to the model's padding side and padding index)
            among:
            * :obj:`True` or :obj:`'longest'`: Pad to the longest sequence in the batch (or no padding if only a single
              sequence if provided).
            * :obj:`'max_length'`: Pad to a maximum length specified with the argument :obj:`max_length` or to the
              maximum acceptable input length for the model if that argument is not provided.
            * :obj:`False` or :obj:`'do_not_pad'` (default): No padding (i.e., can output a batch with sequences of
              different lengths).
        max_length (:obj:`int`, `optional`):
            Maximum length of the ``input_values`` of the returned list and optionally padding length (see above).
        max_length_labels (:obj:`int`, `optional`):
            Maximum length of the ``labels`` returned list and optionally padding length (see above).
        pad_to_multiple_of (:obj:`int`, `optional`):
            If set will pad the sequence to a multiple of the provided value.
            This is especially useful to enable the use of Tensor Cores on NVIDIA hardware with compute capability >=
            7.5 (Volta).
    """

    processor: Wav2Vec2Processor
    padding: Union[bool, str] = True
    max_length: Optional[int] = None
    max_length_labels: Optional[int] = None
    pad_to_multiple_of: Optional[int] = None
    pad_to_multiple_of_labels: Optional[int] = None

    def __call__(self, features: List[Dict[str, Union[List[int], torch.Tensor]]]) -> Dict[str, torch.Tensor]:
        # split inputs and labels since they have to be of different lenghts and need
        # different padding methods
        input_features = [{"input_values": feature["input_values"]} for feature in features]
        label_features = [{"input_ids": feature["labels"]} for feature in features]

        batch = self.processor.pad(
            input_features,
            padding=self.padding,
            max_length=self.max_length,
            pad_to_multiple_of=self.pad_to_multiple_of,
            return_tensors="pt",
        )
        with self.processor.as_target_processor():
            labels_batch = self.processor.pad(
                label_features,
                padding=self.padding,
                max_length=self.max_length_labels,
                pad_to_multiple_of=self.pad_to_multiple_of_labels,
                return_tensors="pt",
            )

        # replace padding with -100 to ignore loss correctly
        labels = labels_batch["input_ids"].masked_fill(labels_batch.attention_mask.ne(1), -100)

        batch["labels"] = labels

        return batch

class CommonVoiceTrainer(Trainer):

    def _get_train_sampler(self):
        if isinstance(self.train_dataset, torch.utils.data.IterableDataset) or not isinstance(
            self.train_dataset, collections.abc.Sized
        ):
            return None

        if self.args.world_size <= 1:
            return RandomSampler(self.train_dataset)
        elif self.args.parallel_mode == ParallelMode.TPU and not self.args.dataloader_drop_last:
            # Use a loop for TPUs when drop_last is False to have all batches have the same size.
            return DistributedSamplerWithLoop(
                self.train_dataset,
                batch_size=self.args.per_device_train_batch_size,
                num_replicas=self.args.world_size,
                rank=self.args.process_index,
            )
        else:
            return DistributedSampler(
                self.train_dataset, num_replicas=self.args.world_size, rank=self.args.process_index
            )

    def get_train_dataloader(self):
        if self.train_dataset is None:
            raise ValueError("Trainer: training requires a train_dataset.")
        train_sampler = self._get_train_sampler()

        return DataLoader(
            self.train_dataset,
            batch_size=self.args.train_batch_size,
            sampler=train_sampler,
            collate_fn=self.data_collator,
            drop_last=self.args.dataloader_drop_last,
            num_workers=self.args.dataloader_num_workers,
            pin_memory=self.args.dataloader_pin_memory,
        )

    def _get_eval_sampler(self, eval_dataset):
        if self.args.local_rank != -1:
            return SequentialDistributedSampler(eval_dataset)
        else:
            return SequentialSampler(eval_dataset)


    def get_eval_dataloader(self, eval_dataset: Optional[Dataset] = None):
        eval_dataset = eval_dataset if eval_dataset is not None else self.eval_dataset
        eval_sampler = self._get_eval_sampler(eval_dataset)

        return DataLoader(
            eval_dataset,
            sampler=eval_sampler,
            batch_size=self.args.eval_batch_size,
            collate_fn=self.data_collator,
            drop_last=self.args.dataloader_drop_last,
            num_workers=self.args.dataloader_num_workers,
            pin_memory=self.args.dataloader_pin_memory,
        )

# %%
from transformers import Trainer, TrainingArguments
from transformers import Wav2Vec2ForCTC
import collections
from torch.utils.data.sampler import RandomSampler, SequentialSampler
from torch.utils.data import DataLoader
from transformers.trainer import (
    SequentialDistributedSampler,
    SequentialSampler,
    ParallelMode,
)

# Load the model and processor
model = Wav2Vec2ForCTC.from_pretrained("anuragshas/wav2vec2-large-xlsr-53-telugu")

# Define training arguments
training_args = TrainingArguments(
    output_dir="./results",
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_eval_batch_size=1,
    warmup_steps=500,
    weight_decay=0.01,
    logging_dir="./logs",
    logging_steps=10,
    group_by_length=True,
    per_device_train_batch_size=16,
    gradient_accumulation_steps=2,
    num_train_epochs=10,
    fp16=False,
    save_steps=10, # Just for demo, change it
    eval_steps=10, # Just for demo, change it
    save_total_limit=2,
    dataloader_num_workers=4,
)

data_collator = DataCollatorCTCWithPadding(processor=processor, padding=True)

def compute_metrics(pred):
    pred_logits = pred.predictions
    pred_ids = np.argmax(pred_logits, axis=-1)

    pred.label_ids[pred.label_ids == -100] = processor.tokenizer.pad_token_id

    pred_str = processor.batch_decode(pred_ids)
    # we do not want to group tokens when computing the metrics
    label_str = processor.batch_decode(pred.label_ids, group_tokens=False)

    wer = wer_metric.compute(predictions=pred_str, references=label_str)

    return {"wer": wer}

trainer = CommonVoiceTrainer(
    model=model,
    data_collator=data_collator,
    args=training_args,
    compute_metrics=compute_metrics,
    train_dataset=dataset['train'],
    eval_dataset=dataset['validation'],
    tokenizer=processor.feature_extractor,
)

# # Start training
trainer.train()
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/configuration_utils.py:364: UserWarning: Passing `gradient_checkpointing` to a config initialization is deprecated and will be removed in v5 Transformers. Using `model.gradient_checkpointing_enable()` instead, or if you are using the `Trainer` API, pass `gradient_checkpointing=True` in your `TrainingArguments`.
#   warnings.warn(
# Some weights of the model checkpoint at anuragshas/wav2vec2-large-xlsr-53-telugu were not used when initializing Wav2Vec2ForCTC: ['wav2vec2.encoder.pos_conv_embed.conv.weight_g', 'wav2vec2.encoder.pos_conv_embed.conv.weight_v']
# - This IS expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# ...

# %%
import gc
import torch

# Clear all variables
for var in dir():
    if var[0] != "_":
        del globals()[var]

# Clear GPU cache
torch.cuda.empty_cache()

# Run garbage collector
gc.collect()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-a0324e25c815> in <cell line: 10>()
#       8
#       9 # Clear GPU cache
# ---> 10 torch.cuda.empty_cache()
#      11
#      12 # Run garbage collector
#
# NameError: name 'torch' is not defined

# %%
# !nvidia-smi
# Out:
# Mon Sep 30 14:46:13 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   58C    P0              29W /  70W |  14613MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install langdetect
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 19.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993222 sha256=04009044d5a0afde5c3424c89274fd431a8de51b4274b30f48543762c9230701
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
# Successfully built langdetect
# ...

# %%
# !pip install flask-socketio
# !pip install eventlet
# !pip install pyngrok
# !pip install deep-translator
# !pip install deep-translator[ai]

# %%
# !ngrok authtoken 2mrsen2D4H4loh6JYyoPBevvlLy_6R9jgTii7FhFdXDaS8LLz
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
# !pip install python-socketio

# %%
# !pip install flask_cors

# %%
# Main

# %%
from flask import Flask, request
from flask_socketio import SocketIO, emit, join_room
from pyngrok import ngrok
import torch
import librosa
from transformers import Wav2Vec2Processor, Wav2Vec2ForCTC
from deep_translator import GoogleTranslator
from flask_cors import CORS  # Add CORS

# Initialize Flask app and SocketIO
app = Flask(__name__)
CORS(app)  # Allow CORS for all routes for now
socketio_server = SocketIO(app, cors_allowed_origins="*", ping_timeout=60000, ping_interval=25000)

# Load the processors and models for Telugu and Hindi
processor_telugu = Wav2Vec2Processor.from_pretrained("anuragshas/wav2vec2-large-xlsr-53-telugu")
model_telugu = Wav2Vec2ForCTC.from_pretrained("anuragshas/wav2vec2-large-xlsr-53-telugu")

processor_hindi = Wav2Vec2Processor.from_pretrained("shiwangi27/wave2vec2-large-xlsr-hindi")
model_hindi = Wav2Vec2ForCTC.from_pretrained("shiwangi27/wave2vec2-large-xlsr-hindi")

# Move models to the appropriate device (CPU or GPU)
device = "cuda" if torch.cuda.is_available() else "cpu"
model_telugu.to(device)
model_hindi.to(device)

# Keep track of connected clients and their roles
clients = {}
ROOM = 'communication_room'

@app.route('/transcribe', methods=['POST'])
def transcribe():
    # Get the language code, audio file, and client ID from the request
    language = request.form.get('language')  # 'te' or 'hi'
    audio_file = request.files['file']
    sender_id = request.form.get('sender_id')  # ID of the client sending the request

    # Load the audio file
    audio, rate = librosa.load(audio_file, sr=16000)

    # Depending on the language, use the respective model and processor
    if language == 'te':
        inputs = processor_telugu(audio, sampling_rate=16000, return_tensors="pt").to(device)
        model = model_telugu
        target_language = 'hi'  # Translate to Hindi if Telugu audio
    elif language == 'hi':
        inputs = processor_hindi(audio, sampling_rate=16000, return_tensors="pt").to(device)
        model = model_hindi
        target_language = 'te'  # Translate to Telugu if Hindi audio
    else:
        return {"error": "Invalid language code"}

    # Generate transcription using the appropriate model
    with torch.no_grad():
        logits = model(**inputs).logits
        predicted_ids = torch.argmax(logits, dim=-1)
        transcription = processor_telugu.batch_decode(predicted_ids)[0] if language == 'te' else processor_hindi.batch_decode(predicted_ids)[0]

    # Translate the transcription
    translation = GoogleTranslator(source=language, target=target_language).translate(transcription)

    # Emit the transcription and translation only to the other client
    for role, client_id in clients.items():
        if client_id != sender_id:
            socketio_server.emit('receive_translation', {'transcription': transcription, 'translation': translation}, room=client_id)

    return {'transcription': transcription, 'translation': translation}


# Handle client connection and assignment as client1 or client2
@socketio_server.on('connect')
def handle_connect():
    client_id = request.sid
    if 'client1' not in clients:
        clients['client1'] = client_id
        join_room(ROOM, sid=client_id)
        emit('client_role', {'role': 'client1'}, room=client_id)
        print(f"Client1 connected: {client_id}")
    elif 'client2' not in clients:
        clients['client2'] = client_id
        join_room(ROOM, sid=client_id)
        emit('client_role', {'role': 'client2'}, room=client_id)
        print(f"Client2 connected: {client_id}")
    else:
        emit('server_full', {'message': 'Server is full, only two clients allowed.'}, room=client_id)
        print(f"Connection attempt rejected for {client_id}")

# Handle client disconnection
@socketio_server.on('disconnect')
def handle_disconnect():
    client_id = request.sid
    if client_id == clients.get('client1'):
        del clients['client1']
        print("Client1 disconnected")
    elif client_id == clients.get('client2'):
        del clients['client2']
        print("Client2 disconnected")

# Start ngrok to tunnel the Flask app
public_url = ngrok.connect(5000)
print("Public URL:", public_url)

# Run the app
if __name__ == '__main__':
    socketio_server.run(app, port=5000)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:104: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/configuration_utils.py:306: UserWarning: Passing `gradient_checkpointing` to a config initialization is deprecated and will be removed in v5 Transformers. Using `model.gradient_checkpointing_enable()` instead, or if you are using the `Trainer` API, pass `gradient_checkpointing=True` in your `TrainingArguments`.
#   warnings.warn(
# Invalid model-index. Not loading eval results into CardData.
# ...

# %%
# from flask import Flask, request
# from flask_socketio import SocketIO, emit, join_room
# from pyngrok import ngrok
# import torch
# import librosa
# from transformers import Wav2Vec2Processor, Wav2Vec2ForCTC
# from deep_translator import GoogleTranslator

# # Initialize Flask app and SocketIO
# app = Flask(__name__)
# socketio_server = SocketIO(app)

# # Load the processor and models
# processor_telugu = Wav2Vec2Processor.from_pretrained("anuragshas/wav2vec2-large-xlsr-53-telugu")
# model_telugu = Wav2Vec2ForCTC.from_pretrained("anuragshas/wav2vec2-large-xlsr-53-telugu")

# processor_hindi = Wav2Vec2Processor.from_pretrained("shiwangi27/wave2vec2-large-xlsr-hindi")
# model_hindi = Wav2Vec2ForCTC.from_pretrained("shiwangi27/wave2vec2-large-xlsr-hindi")

# # Move models to the appropriate device (CPU or GPU)
# device = "cuda" if torch.cuda.is_available() else "cpu"
# model_telugu.to(device)
# model_hindi.to(device)

# # Keep track of connected clients and their roles
# clients = {}
# ROOM = 'communication_room'

# # Route for transcribing audio and translating
# @app.route('/transcribe', methods=['POST'])
# def transcribe():
#     # Get the audio file from the request
#     audio_file = request.files['file']
#     audio, rate = librosa.load(audio_file, sr=16000)

#     # Process the audio for both models (Telugu and Hindi)
#     inputs_telugu = processor_telugu(audio, sampling_rate=16000, return_tensors="pt").to(device)
#     inputs_hindi = processor_hindi(audio, sampling_rate=16000, return_tensors="pt").to(device)

#     # Generate logits for both languages
#     with torch.no_grad():
#         logits_telugu = model_telugu(**inputs_telugu).logits
#         logits_hindi = model_hindi(**inputs_hindi).logits

#     # Calculate confidence levels (higher max logit = higher confidence)
#     telugu_confidence = torch.max(logits_telugu, dim=-1).values.mean().item()
#     hindi_confidence = torch.max(logits_hindi, dim=-1).values.mean().item()

#     # Compare confidence and choose the language
#     if telugu_confidence > hindi_confidence:
#         transcription = processor_telugu.batch_decode(torch.argmax(logits_telugu, dim=-1))[0]
#         detected_language = "Telugu"
#         translation = GoogleTranslator(source='te', target='hi').translate(transcription)
#     else:
#         transcription = processor_hindi.batch_decode(torch.argmax(logits_hindi, dim=-1))[0]
#         detected_language = "Hindi"
#         translation = GoogleTranslator(source='hi', target='te').translate(transcription)

#     # Emit the transcription and translation to both clients in the room
#     socketio_server.emit('receive_translation', {
#         'transcription': transcription,
#         'translation': translation,
#         'detected_language': detected_language
#     }, room=ROOM)

#     return {'transcription': transcription, 'translation': translation, 'detected_language': detected_language}

# # Handle client connection and assignment as client1 or client2
# @socketio_server.on('connect')
# def handle_connect():
#     client_id = request.sid
#     if 'client1' not in clients:
#         clients['client1'] = client_id
#         join_room(ROOM, sid=client_id)
#         emit('client_role', {'role': 'client1'}, room=client_id)
#         print(f"Client1 connected: {client_id}")
#     elif 'client2' not in clients:
#         clients['client2'] = client_id
#         join_room(ROOM, sid=client_id)
#         emit('client_role', {'role': 'client2'}, room=client_id)
#         print(f"Client2 connected: {client_id}")
#     else:
#         emit('server_full', {'message': 'Server is full, only two clients allowed.'}, room=client_id)
#         print(f"Connection attempt rejected for {client_id}")

# # Handle client disconnection
# @socketio_server.on('disconnect')
# def handle_disconnect():
#     client_id = request.sid
#     if client_id == clients.get('client1'):
#         del clients['client1']
#         print("Client1 disconnected")
#     elif client_id == clients.get('client2'):
#         del clients['client2']
#         print("Client2 disconnected")

# # Start ngrok to tunnel the Flask app
# public_url = ngrok.connect(5000)
# print("Public URL:", public_url)

# # Run the app
# if __name__ == '__main__':
#     socketio_server.run(app, port=5000)

from flask import Flask, request
from flask_socketio import SocketIO, emit, join_room
from pyngrok import ngrok
import torch
import librosa
from transformers import Wav2Vec2Processor, Wav2Vec2ForCTC
from deep_translator import GoogleTranslator

# Initialize Flask app and SocketIO
app = Flask(__name__)
socketio_server = SocketIO(app)

# Load the processor and models
processor_telugu = Wav2Vec2Processor.from_pretrained("anuragshas/wav2vec2-large-xlsr-53-telugu")
model_telugu = Wav2Vec2ForCTC.from_pretrained("anuragshas/wav2vec2-large-xlsr-53-telugu")

processor_hindi = Wav2Vec2Processor.from_pretrained("shiwangi27/wave2vec2-large-xlsr-hindi")
model_hindi = Wav2Vec2ForCTC.from_pretrained("shiwangi27/wave2vec2-large-xlsr-hindi")

# Move models to the appropriate device (CPU or GPU)
device = "cuda" if torch.cuda.is_available() else "cpu"
model_telugu.to(device)
model_hindi.to(device)

# Keep track of connected clients and their roles
clients = {}
ROOM = 'communication_room'

# Route for transcribing audio and translating based on client role
@app.route('/transcribe/<client_role>', methods=['POST'])
def transcribe(client_role):
    # Get the audio file from the request
    audio_file = request.files['file']
    audio, rate = librosa.load(audio_file, sr=16000)

    if client_role == 'client1':
        # Client 1 speaks Hindi, translate to Telugu
        inputs_hindi = processor_hindi(audio, sampling_rate=16000, return_tensors="pt").to(device)

        # Generate logits for Hindi model
        with torch.no_grad():
            logits_hindi = model_hindi(**inputs_hindi).logits

        # Get transcription in Hindi
        transcription = processor_hindi.batch_decode(torch.argmax(logits_hindi, dim=-1))[0]
        detected_language = "Hindi"

        # Translate Hindi transcription to Telugu
        translation = GoogleTranslator(source='hi', target='te').translate(transcription)

    elif client_role == 'client2':
        # Client 2 speaks Telugu, translate to Hindi
        inputs_telugu = processor_telugu(audio, sampling_rate=16000, return_tensors="pt").to(device)

        # Generate logits for Telugu model
        with torch.no_grad():
            logits_telugu = model_telugu(**inputs_telugu).logits

        # Get transcription in Telugu
        transcription = processor_telugu.batch_decode(torch.argmax(logits_telugu, dim=-1))[0]
        detected_language = "Telugu"

        # Translate Telugu transcription to Hindi
        translation = GoogleTranslator(source='te', target='hi').translate(transcription)

    else:
        return {'error': 'Invalid client role'}, 400

    # Emit the transcription and translation to both clients in the room
    socketio_server.emit('receive_translation', {
        'transcription': transcription,
        'translation': translation,
        'detected_language': detected_language,
        'client_role': client_role
    }, room=ROOM)

    return {'transcription': transcription, 'translation': translation, 'detected_language': detected_language}

# Handle client connection and assignment as client1 or client2
@socketio_server.on('connect')
def handle_connect():
    client_id = request.sid
    if 'client1' not in clients:
        clients['client1'] = client_id
        join_room(ROOM, sid=client_id)
        emit('client_role', {'role': 'client1'}, room=client_id)
        print(f"Client1 connected: {client_id}")
    elif 'client2' not in clients:
        clients['client2'] = client_id
        join_room(ROOM, sid=client_id)
        emit('client_role', {'role': 'client2'}, room=client_id)
        print(f"Client2 connected: {client_id}")
    else:
        emit('server_full', {'message': 'Server is full, only two clients allowed.'}, room=client_id)
        print(f"Connection attempt rejected for {client_id}")

# Handle client disconnection
@socketio_server.on('disconnect')
def handle_disconnect():
    client_id = request.sid
    if client_id == clients.get('client1'):
        del clients['client1']
        print("Client1 disconnected")
    elif client_id == clients.get('client2'):
        del clients['client2']
        print("Client2 disconnected")

# Start ngrok to tunnel the Flask app
public_url = ngrok.connect(5000)
print("Public URL:", public_url)

# Run the app
if __name__ == '__main__':
    socketio_server.run(app, port=5000)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# preprocessor_config.json:   0%|          | 0.00/158 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/138 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.56k [00:00<?, ?B/s]
# ...

# %%
# New Trial

# %%
from flask import Flask, request, send_file
import requests  # For calling the TTS API
import io  # For audio handling
import os  # To manage temporary files

from flask import Flask, request
from flask_socketio import SocketIO, emit, join_room
from pyngrok import ngrok
import torch
import librosa
from transformers import Wav2Vec2Processor, Wav2Vec2ForCTC
from deep_translator import GoogleTranslator

# Initialize Flask app and SocketIO
app = Flask(__name__)
socketio_server = SocketIO(app)

# Load the processor and models
processor_telugu = Wav2Vec2Processor.from_pretrained("anuragshas/wav2vec2-large-xlsr-53-telugu")
model_telugu = Wav2Vec2ForCTC.from_pretrained("anuragshas/wav2vec2-large-xlsr-53-telugu")

processor_hindi = Wav2Vec2Processor.from_pretrained("shiwangi27/wave2vec2-large-xlsr-hindi")
model_hindi = Wav2Vec2ForCTC.from_pretrained("shiwangi27/wave2vec2-large-xlsr-hindi")

device = "cuda" if torch.cuda.is_available() else "cpu"
model_telugu.to(device)
model_hindi.to(device)

clients = {}
ROOM = 'communication_room'

# Helper function for TTS
def synthesize_speech(text, client_role):
    response = requests.post(
        "TTS_API_ENDPOINT",  # Replace with the actual TTS API endpoint
        headers={"Authorization": "Bearer YOUR_API_KEY"},
        json={
            "text": text,
            "voice": "voice_id"  # Replace with the client-specific voice ID
        }
    )

    if response.status_code == 200:
        return response.content  # Audio bytes from TTS API
    else:
        print("TTS API request failed:", response.status_code, response.text)
        return None

# Route for transcribing audio and translating based on client role
@app.route('/transcribe/<client_role>', methods=['POST'])
def transcribe(client_role):
    # Get the audio file from the request
    audio_file = request.files['file']
    audio, rate = librosa.load(audio_file, sr=16000)

    if client_role == 'client1':
        # Client 1 speaks Hindi, translate to Telugu
        inputs_hindi = processor_hindi(audio, sampling_rate=16000, return_tensors="pt").to(device)
        with torch.no_grad():
            logits_hindi = model_hindi(**inputs_hindi).logits
        transcription = processor_hindi.batch_decode(torch.argmax(logits_hindi, dim=-1))[0]
        translation = GoogleTranslator(source='hi', target='te').translate(transcription)
        detected_language = "Hindi"

    elif client_role == 'client2':
        # Client 2 speaks Telugu, translate to Hindi
        inputs_telugu = processor_telugu(audio, sampling_rate=16000, return_tensors="pt").to(device)
        with torch.no_grad():
            logits_telugu = model_telugu(**inputs_telugu).logits
        transcription = processor_telugu.batch_decode(torch.argmax(logits_telugu, dim=-1))[0]
        translation = GoogleTranslator(source='te', target='hi').translate(transcription)
        detected_language = "Telugu"

    else:
        return {'error': 'Invalid client role'}, 400

    # Use TTS API to convert translated text to audio in a similar voice
    audio_content = synthesize_speech(translation, client_role)

    if audio_content:
        audio_path = f"temp_audio_{client_role}.wav"
        with open(audio_path, "wb") as f:
            f.write(audio_content)

        # Emit both text and audio to the clients
        socketio_server.emit('receive_translation_audio', {
            'transcription': transcription,
            'translation': translation,
            'detected_language': detected_language,
            'client_role': client_role
        }, room=ROOM)

        return send_file(audio_path, as_attachment=True, mimetype="audio/wav")
    else:
        return {'error': 'TTS synthesis failed'}, 500

# Handle client connection and assignment as client1 or client2
@socketio_server.on('connect')
def handle_connect():
    client_id = request.sid
    if 'client1' not in clients:
        clients['client1'] = client_id
        join_room(ROOM, sid=client_id)
        emit('client_role', {'role': 'client1'}, room=client_id)
        print(f"Client1 connected: {client_id}")
    elif 'client2' not in clients:
        clients['client2'] = client_id
        join_room(ROOM, sid=client_id)
        emit('client_role', {'role': 'client2'}, room=client_id)
        print(f"Client2 connected: {client_id}")
    else:
        emit('server_full', {'message': 'Server is full, only two clients allowed.'}, room=client_id)
        print(f"Connection attempt rejected for {client_id}")

# Handle client disconnection
@socketio_server.on('disconnect')
def handle_disconnect():
    client_id = request.sid
    if client_id == clients.get('client1'):
        del clients['client1']
        print("Client1 disconnected")
    elif client_id == clients.get('client2'):
        del clients['client2']
        print("Client2 disconnected")

public_url = ngrok.connect(5000)
print("Public URL:", public_url)

if __name__ == '__main__':
    socketio_server.run(app, port=5000)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/configuration_utils.py:364: UserWarning: Passing `gradient_checkpointing` to a config initialization is deprecated and will be removed in v5 Transformers. Using `model.gradient_checkpointing_enable()` instead, or if you are using the `Trainer` API, pass `gradient_checkpointing=True` in your `TrainingArguments`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# ...

# %%
camera = CameraStream(constraints={'audio': True,'video':False})
recorder = AudioRecorder(stream=camera)
recorder
# Out:
# AudioRecorder(audio=Audio(value=b'', format='webm'), stream=CameraStream(constraints={'audio': True, 'video': …

# %%
with open('recording.webm', 'wb') as f:
    f.write(recorder.audio.value)
# !ffmpeg -i recording.webm -ac 1 -f wav my_recording.wav -y -hide_banner -loglevel panic

# %%
# Load audio file
audio, rate = librosa.load("my_recording.wav", sr=16000)

# Process audio
inputs = processor(audio, sampling_rate=16000, return_tensors="pt")

inputs = {key: value.half().to("cuda") for key, value in inputs.items()}

# Ensure attention mask is set
if "attention_mask" not in inputs:
    inputs['attention_mask'] = torch.ones(inputs['input_features'].shape, dtype=torch.long)

# Generate transcription
with torch.no_grad():
    predicted_ids = model.generate(inputs["input_features"], attention_mask=inputs["attention_mask"])

# Decode the transcription
transcription = processor.batch_decode(predicted_ids, skip_special_tokens=True)[0]
print(f"Transcription: {transcription}")

# Detect language of the transcribed text
detected_language = detect(transcription)
print(f"Detected Language: {detected_language}")
# Out:
# Transcription:  अने की माडा वन्तेद
# Detected Language: hi
